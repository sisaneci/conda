# %%
print('first output')
# Out:
# first output

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

a = np.array([1,2,3])
b = np.array([4,5,6])
c = a*b

fig, myplot = plt.subplots()

plt.plot(c)
plt.show()
