# %%
print('first output')
# Out:
# first output

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

a = np.array([1,2,3])
b = np.array([4,5,6])
c = a*b

fig, myplot = plt.subplots()

plt.plot(c)
plt.show()

# %%
a = np.array([1,2,4,16,45,90,133,179,188,200,201,202,203,220,223,225,230,250])
b = np.diff(a)
c = np.trapz(a)

fig, myplot = plt.subplots()

plt.plot(a)
plt.plot(b)
#plt.plot(c)

plt.show()
print(np.size(a))
print(np.size(b))
print(np.size(c))
# Out:
# 18
# 17
# 1
